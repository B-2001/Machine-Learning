# %% [markdown]
# # **Unsupervised Learning on Country Data**
#
# * Dataset link: [https://www.kaggle.com/datasets/rohan0301/unsupervised-learning-on-country-data/data?select=Country-data.csv](https://www.kaggle.com/datasets/rohan0301/unsupervised-learning-on-country-data/data?select=Country-data.csv)
#
# * in this project, we are going to classify countries into 3 categories - developed country, developing country, poor (Least Developed) based on economic and health factors from the country dataset.
#
# * Dataset Description:
#
#     | **Column Name** | **Description** |
#     |-----------------|-----------------|
#     | `country`       | Name of the country |
#     | `child_mort`    | Death of children under 5 years of age per 1000 live births |
#     | `exports`       | Exports of goods and services per capita, given as % of the GDP per capita |
#     | `health`        | Total health spending per capita, given as % of GDP per capita |
#     | `imports`       | Imports of goods and services per capita, given as % of the GDP per capita |
#     | `income`        | Net income per person |
#     | `inflation`     | The measurement of the annual growth rate of the Total GDP |
#     | `life_expec`    | The average number of years a newborn child would live if current mortality patterns remain the same |
#     | `total_fer`     | The number of children that would be born to each woman if the current age-fertility rates remain the same |
#     | `gdpp`          | The GDP per capita, calculated as the Total GDP divided by the total population |

# %% [markdown]
# ### Import neccessary libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as exp
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %% [markdown]
# # # Data Collection

# %%
df = pd.read_csv(r'Dataset\country_data.csv')
df
# Out:
#                  country  child_mort  exports  health  imports  income  \
# 0            Afghanistan        90.2     10.0    7.58     44.9    1610
# 1                Albania        16.6     28.0    6.55     48.6    9930
# 2                Algeria        27.3     38.4    4.17     31.4   12900
# 3                 Angola       119.0     62.3    2.85     42.9    5900
# 4    Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# ..                   ...         ...      ...     ...      ...     ...
# 162              Vanuatu        29.2     46.6    5.25     52.7    2950
# 163            Venezuela        17.1     28.5    4.91     17.6   16500
# 164              Vietnam        23.3     72.0    6.84     80.2    4490
# 165                Yemen        56.3     30.0    5.18     34.4    4480
# 166               Zambia        83.1     37.0    5.89     30.9    3280
#
#      inflation  life_expec  total_fer   gdpp
# 0         9.44        56.2       5.82    553
# ...

# %%
data_dict = pd.read_csv(r'Dataset\data-dictionary.csv')
data_dict
# Out:
#   Column Name                                        Description
# 0     country                                Name of the country
# 1  child_mort  Death of children under 5 years of age per 100...
# 2     exports  Exports of goods and services per capita. Give...
# 3      health  Total health spending per capita. Given as %ag...
# 4     imports  Imports of goods and services per capita. Give...
# 5      Income                              Net income per person
# 6   Inflation  The measurement of the annual growth rate of t...
# 7  life_expec  The average number of years a new born child w...
# 8   total_fer  The number of children that would be born to e...
# 9        gdpp  The GDP per capita. Calculated as the Total GD...

# %% [markdown]
# # # EDA

# %%
df.corr()
# Out:
#             child_mort   exports    health   imports    income  inflation  \
# child_mort    1.000000 -0.318093 -0.200402 -0.127211 -0.524315   0.288276
# exports      -0.318093  1.000000 -0.114408  0.737381  0.516784  -0.107294
# health       -0.200402 -0.114408  1.000000  0.095717  0.129579  -0.255376
# imports      -0.127211  0.737381  0.095717  1.000000  0.122406  -0.246994
# income       -0.524315  0.516784  0.129579  0.122406  1.000000  -0.147756
# inflation     0.288276 -0.107294 -0.255376 -0.246994 -0.147756   1.000000
# life_expec   -0.886676  0.316313  0.210692  0.054391  0.611962  -0.239705
# total_fer     0.848478 -0.320011 -0.196674 -0.159048 -0.501840   0.316921
# gdpp         -0.483032  0.418725  0.345966  0.115498  0.895571  -0.221631
#
#             life_expec  total_fer      gdpp
# child_mort   -0.886676   0.848478 -0.483032
# exports       0.316313  -0.320011  0.418725
# health        0.210692  -0.196674  0.345966
# imports       0.054391  -0.159048  0.115498
# ...

# %%
fig = plt.figure(figsize=(12,10))
ax = sns.heatmap(df.corr(),annot=True,cmap = 'viridis')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
scalar = MinMaxScaler()

# %%
scaled_data = scalar.fit_transform(df.drop('country',axis = 1))

# %%
scaled_df = pd.DataFrame(data = scaled_data,columns=df.columns[1:])
scaled_df['country'] = df['country']
scaled_df
# Out:
#      child_mort   exports    health   imports    income  inflation  \
# 0      0.426485  0.049482  0.358608  0.257765  0.008047   0.126144
# 1      0.068160  0.139531  0.294593  0.279037  0.074933   0.080399
# 2      0.120253  0.191559  0.146675  0.180149  0.098809   0.187691
# 3      0.566699  0.311125  0.064636  0.246266  0.042535   0.245911
# 4      0.037488  0.227079  0.262275  0.338255  0.148652   0.052213
# ..          ...       ...       ...       ...       ...        ...
# 162    0.129503  0.232582  0.213797  0.302609  0.018820   0.063118
# 163    0.070594  0.142032  0.192666  0.100809  0.127750   0.463081
# 164    0.100779  0.359651  0.312617  0.460715  0.031200   0.150725
# 165    0.261441  0.149536  0.209447  0.197397  0.031120   0.257000
# 166    0.391918  0.184556  0.253574  0.177275  0.021473   0.168284
#
#      life_expec  total_fer      gdpp              country
# 0      0.475345   0.736593  0.003073          Afghanistan
# ...

# %%
exp.histogram(data_frame=df,x = 'gdpp',nbins=167,opacity=0.75,barmode='overlay')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="356e6021-66cf-4e07-b894-3cf0ef396fb4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("356e6021-66cf-4e07-b894-3cf0ef396fb4")) {
#                     Plotly.newPlot(
# ...

# %%
exp.scatter(data_frame=df,x = 'child_mort',y = 'health',color='country')
# Out:
# <div>
#
#
#             <div id="fceaa389-97ea-481c-9a2d-9270e9298707" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("fceaa389-97ea-481c-9a2d-9270e9298707")) {
#                     Plotly.newPlot(
#                         'fceaa389-97ea-481c-9a2d-9270e9298707',
# ...

# %%
data = scaled_df.drop('country',axis = 1)

# %%
# Calculate sum of squared distances
ssd = []
K = range(1,10)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(data)
    ssd.append(km.inertia_)

# %%
plt.figure(figsize=(10,6))
plt.plot(K, ssd, 'bx-')
plt.xlabel('k')
plt.ylabel('ssd')
plt.title('Elbow Method For Optimal k')
plt.show()

# %% [markdown]
# # # Kmeans Clustering implemendation

# %%
kmean = KMeans(n_clusters=3)
kmean.fit(data)
# Out:
# KMeans(n_clusters=3)

# %%
pred = kmean.labels_
print(pred)
# Out:
# [0 2 2 0 2 2 2 1 1 2 2 2 2 2 2 1 2 0 2 2 2 2 2 1 2 0 0 2 0 1 2 0 0 2 2 2 0
#  0 0 2 0 2 1 1 1 2 2 2 2 0 0 2 2 1 1 0 0 2 1 0 1 2 2 0 0 2 0 2 1 2 2 2 0 1
#  1 1 2 1 2 2 0 0 1 2 0 2 2 0 0 2 2 1 2 0 0 2 2 0 1 0 2 2 2 2 2 2 0 2 0 2 1
#  1 0 0 1 2 0 2 2 2 2 2 1 1 2 2 0 2 2 0 2 2 0 1 1 1 0 2 1 1 2 2 0 2 1 1 2 0
#  2 0 0 2 2 2 2 0 2 1 1 1 2 2 2 2 2 0 0]

# %%
exp.scatter(data_frame= df,x = 'gdpp',y = 'income',color=kmean.labels_)
# Out:
# <div>
#
#
#             <div id="076f5642-a96f-4350-9ac5-663a8fb7f160" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("076f5642-a96f-4350-9ac5-663a8fb7f160")) {
#                     Plotly.newPlot(
#                         '076f5642-a96f-4350-9ac5-663a8fb7f160',
# ...

# %% [markdown]
# # # PCA implemendation

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pca_model = pca.fit_transform(data)
data_transform = pd.DataFrame(data = pca_model, columns = ['PCA1', 'PCA2'])
data_transform['Cluster'] = pred

# %%
data_transform.head()
# Out:
#        PCA1      PCA2  Cluster
# 0 -0.599078  0.095490        0
# 1  0.158474 -0.212092        2
# 2  0.003686 -0.135867        2
# 3 -0.650235  0.275975        0
# 4  0.200711 -0.064662        2

# %%
plt.figure(figsize=(8,8))
g = sns.scatterplot(data=data_transform, x='PCA1', y='PCA2', palette=sns.color_palette()[:3], hue='Cluster')
title = plt.title('Countries Clusters with PCA')

# %% [markdown]
# |   **Clusters**  | **Term**                             | **Definition**                                                                              |
# | --------------- | ------------------------------------ | ------------------------------------------------------------------------------------------- |
# |        0        | **Developed Country**                | A nation with a high standard of living, advanced infrastructure, and strong economy.       |
# |        1        | **Developing Country**               | A nation that is improving its economy and infrastructure but not yet fully industrialized. |
# |        2        | **Poor Country** *(Least Developed)* | A nation with very low income levels, weak infrastructure, and high poverty.                |
